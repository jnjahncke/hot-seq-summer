# %%
# %%capture
# !pip install matplotlib-venn

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles

# %%
# !python domain_comp.py enriched_domains/mmusculus_downreg_domains.txt enriched_domains/hsapiens_downreg_domains.txt
# Out:
# # list1:	enriched_domains/mmusculus_downreg_domains.txt
# # list2:	enriched_domains/hsapiens_downreg_domains.txt
# # list1 (all):	131
# # list2 (all):	171
# # shared:	11
# # only in list1:	120
# # only in list2:	160
# #
# # Shared enriched domains:
# Olfactory receptor
# Protein kinase C terminal domain
# FGGY family of carbohydrate kinases, C-terminal domain
# Kinesin motor domain
# 5' nucleotidase family
# BRCA1 C Terminus (BRCT) domain
# Calcineurin-like phosphoesterase
# CYRIA/CYRIB Rac1 binding domain
# WD domain, G-beta repeat
# Homeodomain
# DDHD domain

# %%
venn2(subsets = (147,215,15), set_labels = ("Mouse Upregulated", "Human Upregulated"),
     set_colors = ("purple","lightskyblue"), alpha = 0.7);
venn2_circles(subsets = (147,215,15), linewidth = 1)

# %%
# !python domain_comp.py enriched_domains/mmusculus_upreg_domains.txt enriched_domains/scerevisiae_upreg_domains.txt
# Out:
# # list1:	enriched_domains/mmusculus_upreg_domains.txt
# # list2:	enriched_domains/scerevisiae_upreg_domains.txt
# # list1 (all):	162
# # list2 (all):	84
# # shared:	9
# # only in list1:	153
# # only in list2:	75
# #
# # Shared enriched domains:
# Hsp70 protein
# DnaJ C terminal domain
# Homeobox KN domain
# bZIP transcription factor
# Ankyrin repeat
# Der1-like family
# Zinc finger, C2H2 type
# Zinc finger C-x8-C-x5-C-x3-H type (and similar)
# Activator of Hsp90 ATPase, N-terminal

# %%
venn2(subsets = (153,75,9), set_labels = ("Mouse Upregulated", "Yeast Upregulated"),
     set_colors = ("purple","orange"), alpha = 0.7);
venn2_circles(subsets = (153,75,9), linewidth = 1)

# %%
# !python domain_comp.py enriched_domains/hsapiens_upreg_domains.txt enriched_domains/scerevisiae_upreg_domains.txt
# Out:
# # list1:	enriched_domains/hsapiens_upreg_domains.txt
# # list2:	enriched_domains/scerevisiae_upreg_domains.txt
# # list1 (all):	230
# # list2 (all):	84
# # shared:	8
# # only in list1:	222
# # only in list2:	76
# #
# # Shared enriched domains:
# CybS, succinate dehydrogenase cytochrome B small subunit
# Hsp70 protein
# Aldehyde dehydrogenase family
# Carbohydrate/starch-binding module (family 21)
# Activator of Hsp90 ATPase, N-terminal
# alpha/beta hydrolase fold
# DnaJ C terminal domain
# bZIP transcription factor

# %%
venn2(subsets = (222,75,8), set_labels = ("Human Upregulated", "Yeast Upregulated"),
     set_colors = ("lightskyblue","orange"), alpha = 0.7);
venn2_circles(subsets = (222,75,8), linewidth = 1)
